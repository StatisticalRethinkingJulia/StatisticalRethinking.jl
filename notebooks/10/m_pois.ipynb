# %%
using StatisticalRethinking
using Turing

Turing.setadbackend(:reverse_diff)

d = CSV.read(joinpath(dirname(Base.pathof(StatisticalRethinking)), "..", "data",
    "UCBadmit.csv"), delim=';')
size(d) # Should be 12x5

@model m_pois(admit, reject) = begin
   α₁ ~ Normal(0,100)
   α₂ ~ Normal(0,100)

   for i ∈ 1:length(admit)
       λₐ = exp(α₁)
       λᵣ = exp(α₂)
       admit[i] ~ Poisson(λₐ)
       reject[i] ~ Poisson(λᵣ)
   end
end

posterior = sample(m_pois(d[:admit], d[:reject]), Turing.NUTS(2000, 1000, 0.95))
describe(posterior)
# Out:
# ┌ Info: [Turing] looking for good initial eps...
# └ @ Turing /Users/rob/.julia/packages/Turing/xp88X/src/samplers/support/hmc_core.jl:246
# [NUTS{Turing.FluxTrackerAD,Union{}}] found initial ϵ: 0.05
# └ @ Turing /Users/rob/.julia/packages/Turing/xp88X/src/samplers/support/hmc_core.jl:291
# [NUTS] Sampling...  0%  ETA: 2:54:13
#   ϵ:         0.05
#   α:         0.0
#   pre_cond:  [1.0, 1.0]
#
#
# [NUTS] Sampling...  9%  ETA: 0:01:03
#   ϵ:         0.013267943342427549
#   α:         0.9533749276901
#   pre_cond:  [1.0, 1.0]
#
#
# [NUTS] Sampling... 20%  ETA: 0:00:29
#   ϵ:         0.01112249801529372
#   α:         0.9881144546816445
#   pre_cond:  [1.0, 1.0]
#
#
# [NUTS] Sampling... 30%  ETA: 0:00:19
#   ϵ:         0.012364872462807546
#   α:         0.9772171015542457
#   pre_cond:  [1.0, 1.0]
#
#
# [NUTS] Sampling... 44%  ETA: 0:00:12
#   ϵ:         0.016764895016747255
#   α:         1.0
# ┌ Info:  Adapted ϵ = 0.012653178916032518, std = [1.0, 1.0]; 1000 iterations is used for adaption.
# └ @ Turing /Users/rob/.julia/packages/Turing/xp88X/src/samplers/adapt/adapt.jl:91
#
#
#
# [NUTS] Sampling... 58%  ETA: 0:00:07
#   ϵ:         0.012653178916032518
#   α:         0.9986524417911726
#   pre_cond:  [1.0, 1.0]
#
#
# [NUTS] Sampling... 72%  ETA: 0:00:04
#   ϵ:         0.012653178916032518
#   α:         1.0
#   pre_cond:  [1.0, 1.0]
#
#
# [NUTS] Sampling... 86%  ETA: 0:00:02
#   ϵ:         0.012653178916032518
#   α:         0.9355360771098202
#   pre_cond:  [1.0, 1.0]
#
#
# [NUTS] Sampling... 97%  ETA: 0:00:00
#   ϵ:         0.012653178916032518
#   α:         0.9906185953950201
#   pre_cond:  [1.0, 1.0]
#
#
# [NUTS] Sampling...100% Time: 0:00:14
# [NUTS] Finished with
#   Running time        = 13.37881946800003;
#   #lf / sample        = 0.0015;
#   #evals / sample     = 16.746;
#   pre-cond. metric    = [1.0, 1.0].
# Iterations = 1:2000
# Thinning interval = 1
# Chains = 1
# Samples per chain = 2000
#
# Empirical Posterior Estimates:
#                Mean             SD          Naive SE        MCSE          ESS
#   lf_num     0.0015000000   0.0670820393 0.00150000000  0.00150000000 2000.000000
#       α₂     5.4446197539   0.0401944302 0.00089877478  0.00304088818  174.715265
#  elapsed     0.0066894097   0.0932971344 0.00208618735  0.00273167900 1166.479956
#  epsilon     0.0135390205   0.0076348728 0.00017072095  0.00026082997  856.818067
#       α₁     4.9660209879   0.2008620074 0.00449141103  0.01918096707  109.661605
#       lp -1322.9386332028 230.8348152009 5.16162338363 21.38228911529  116.545156
# eval_num    16.7460000000   7.1895290989 0.16076275791  0.16523730941 1893.148416
#   lf_eps     0.0135390205   0.0076348728 0.00017072095  0.00026082997  856.818067
#
# Quantiles:
#                2.5%            25.0%            50.0%           75.0%           97.5%
#   lf_num     0.0000000000     0.000000000     0.0000000000     0.000000000     0.000000000
#       α₂     5.4047452617     5.429068552     5.4417336622     5.454504289     5.479251764
#  elapsed     0.0008393285     0.002019015     0.0040000215     0.004578608     0.010507141
#  epsilon     0.0091394390     0.012653179     0.0126531789     0.013471477     0.018798436
#       α₁     4.9317336611     4.969818192     4.9852780476     5.000194607     5.031194798
#       lp -1304.6642694727 -1302.002905019 -1301.2751723709 -1300.884544492 -1300.648443305
# eval_num     4.0000000000    10.000000000    22.0000000000    22.000000000    22.000000000
#   lf_eps     0.0091394390     0.012653179     0.0126531789     0.013471477     0.018798436

# %% [markdown]
# ERROR: MethodError: no method matching logpdf(::Poisson{Float64}, ::String)
# https://github.com/TuringLang/Turing.jl/issues/615

# %% [markdown]
# Rethinking
#    mean   sd 5.5% 94.5% n_eff Rhat
# a1 4.99 0.02 4.95  5.02  2201    1
# a2 5.44 0.02 5.41  5.47  2468    1

# %% [markdown]
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
