# %% [markdown]
# Load Julia packages (libraries) needed

# %%
using StatisticalRethinking, CmdStan, StanMCMCChains
gr(size=(500,500));

# %% [markdown]
# CmdStan uses a tmp directory to store the output of cmdstan

# %%
ProjDir = rel_path("..", "scripts", "03")
cd(ProjDir)

# %% [markdown]
# Define the Stan language model

# %%
binomialstanmodel = "
// Inferring a Rate
data {
  int N;
  int<lower=0> k[N];
  int<lower=1> n[N];
}
parameters {
  real<lower=0,upper=1> theta;
  real<lower=0,upper=1> thetaprior;
}
model {
  // Prior Distribution for Rate Theta
  theta ~ beta(1, 1);
  thetaprior ~ beta(1, 1);

  // Observed Counts
  k ~ binomial(n, theta);
}
";

# %% [markdown]
# Define the Stanmodel and set the output format to :mcmcchains.

# %%
stanmodel = Stanmodel(name="binomial", monitors = ["theta"], model=binomialstanmodel,
  output_format=:mcmcchains);
# Use 4 observations
N2 = 4
n2 = Int.(9 * ones(Int, N2))
k2 = [6, 5, 7, 6]
# Out:
# 4-element Array{Int64,1}:
#  6
#  5
#  7
#  6

# %% [markdown]
# Input data for cmdstan

# %%
binomialdata = Dict("N" => length(n2), "n" => n2, "k" => k2);

# %% [markdown]
# Sample using cmdstan

# %%
rc, chn, cnames = stan(stanmodel, binomialdata, ProjDir, diagnostics=false,
  CmdStanDir=CMDSTAN_HOME);
# Describe the draws
describe(chn)
# Out:
# Inference for Stan model: binomial_model
# 4 chains: each with iter=(1000,1000,1000,1000); warmup=(0,0,0,0); thin=(1,1,1,1); 4000 iterations saved.
#
# Warmup took (0.025, 0.024, 0.025, 0.025) seconds, 0.099 seconds total
# Sampling took (0.045, 0.043, 0.045, 0.043) seconds, 0.18 seconds total
#
#                 Mean     MCSE  StdDev     5%   50%   95%    N_Eff  N_Eff/s    R_hat
# lp__             -27  3.1e-02     1.2    -29   -27   -26  1.4e+03  8.0e+03  1.0e+00
# accept_stat__   0.92  1.6e-03    0.11   0.69  0.96   1.0  4.6e+03  2.6e+04  1.0e+00
# stepsize__      0.78  2.9e-02   0.041   0.73  0.80  0.83  2.0e+00  1.1e+01  3.2e+13
# treedepth__      2.0  4.6e-02    0.68    1.0   2.0   3.0  2.2e+02  1.3e+03  1.0e+00
# n_leapfrog__     4.8  8.0e-02     4.5    1.0   3.0    15  3.2e+03  1.8e+04  1.0e+00
# divergent__     0.00      nan    0.00   0.00  0.00  0.00      nan      nan      nan
# energy__          28  4.2e-02     1.5     26    28    31  1.3e+03  7.6e+03  1.0e+00
# theta           0.66  1.4e-03   0.076   0.53  0.66  0.78  3.0e+03  1.7e+04  1.0e+00
# thetaprior      0.50  5.2e-03    0.29  0.046  0.50  0.96  3.1e+03  1.8e+04  1.0e+00
#
# Samples were drawn using hmc with nuts.
# For each parameter, N_Eff is a crude measure of effective sample size,
# and R_hat is the potential scale reduction factor on split chains (at
# convergence, R_hat=1).
#
# Log evidence      = 0.0
# Iterations        = 1:1000
# Thinning interval = 1
# Chains            = 1, 2, 3, 4
# Samples per chain = 1000
# parameters        = theta
#
# Empirical Posterior Estimates
# ────────────────────────────────────────
# parameters
#        Mean    SD   Naive SE  MCSE   ESS
# theta 0.6573 0.0759   0.0012 0.0014 1000
#
# Quantiles
# ────────────────────────────────────────
# parameters
#        2.5%  25.0%  50.0%  75.0%  97.5%
# theta 0.4016 0.607 0.6602 0.7114 0.8829

# %% [markdown]
# Look at area of hpd

# %%
MCMCChains.hpd(chn)
# Out:
# Log evidence      = 0.0
# Iterations        = 1:1000
# Thinning interval = 1
# Chains            = 1, 2, 3, 4
# Samples per chain = 1000
# internals         =
# parameters        = theta
#
# parameters
#       95% Lower 95% Upper
# theta  0.509168  0.798152

# %% [markdown]
# Plot the 4 chains

# %%
if rc == 0
  mixeddensity(chn, xlab="height [cm]", ylab="density")
  bnds =MCMCChains.hpd(convert(Vector{Float64}, chn.value[:,1,1]))
  vline!([bnds[1]], line=:dash)
  vline!([bnds[2]], line=:dash)
end
# Out:
# Plot{Plots.GRBackend() n=6}

# %% [markdown]
# End of `clip-06-16s.jl`

# %% [markdown]
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
