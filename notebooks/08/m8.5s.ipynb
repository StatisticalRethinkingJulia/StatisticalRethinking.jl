# %% [markdown]
# Load Julia packages (libraries) needed  for the snippets in chapter 0

# %%
using StatisticalRethinking
using CmdStan, StanMCMCChain
gr(size=(500,500));

# %% [markdown]
# CmdStan uses a tmp directory to store the output of cmdstan

# %%
ProjDir = rel_path("..", "scripts", "08")
cd(ProjDir)

# %% [markdown]
# Define the Stan language model

# %%
m_8_5_model = "
data{
  int N;
  vector[N] y;
}
parameters{
  real sigma;
  real alpha;
  real a1;
  real a2;
}
model{
  real mu;
  a1 ~ normal(0, 10);
  a2 ~ normal(0, 10);
  mu = a1 + a2;
  y ~ normal( mu , sigma );
}
";

# %% [markdown]
# Define the Stanmodel and set the output format to :mcmcchain.

# %%
stanmodel = Stanmodel(name="m_8_5_model", monitors = ["a1", "a2", "mu", "sigma"],
model=m_8_5_model, output_format=:mcmcchain);
# Out:
# File /Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan will be updated.

# %% [markdown]
# Input data for cmdstan

# %%
m_8_5_data = Dict("N" => 100, "y" => rand(Normal(0, 1), 100));

# %% [markdown]
# Sample using cmdstan

# %%
rc, chn, cnames = stan(stanmodel, m_8_5_data, ProjDir, diagnostics=false,
  summary=true, CmdStanDir=CMDSTAN_HOME);

rethinking = "
       mean   sd   5.5% 94.5% n_eff Rhat
a1    -0.08 7.15 -11.34 11.25  1680    1
a2    -0.05 7.15 -11.37 11.19  1682    1
sigma  0.90 0.07   0.81  1.02  2186    1
";
# Out:
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -1.51639, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -3.44705, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -202.912, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -3.03847, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -3.04856, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -3.68757, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -0.327521, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -0.569008, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -563.652, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is -6.04105, but must be > 0!  (in '/Users/rob/.julia/dev/StatisticalRethinking/scripts/08/tmp/m_8_5_model.stan' at line 16)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
#
# Inference for Stan model: m_8_5_model_model
# 4 chains: each with iter=(1000,1000,1000,1000); warmup=(0,0,0,0); thin=(1,1,1,1); 4000 iterations saved.
#
# Warmup took (2.4, 2.6, 2.6, 2.4) seconds, 9.9 seconds total
# Sampling took (2.9, 2.8, 2.8, 2.8) seconds, 11 seconds total
#
#                     Mean     MCSE   StdDev        5%       50%       95%    N_Eff  N_Eff/s    R_hat
# lp__            -4.8e+01  3.2e-02  1.2e+00  -5.1e+01  -4.8e+01  -4.7e+01  1.5e+03  1.3e+02  1.0e+00
# accept_stat__    9.4e-01  1.4e-03  9.1e-02   7.5e-01   9.7e-01   1.0e+00  4.3e+03  3.8e+02  1.0e+00
# stepsize__       1.0e-02  7.5e-04  1.1e-03   9.2e-03   1.0e-02   1.2e-02  2.0e+00  1.8e-01  5.3e+13
# treedepth__      8.3e+00  3.5e-02  2.0e+00   3.0e+00   9.0e+00   1.0e+01  3.4e+03  3.0e+02  1.0e+00
# n_leapfrog__     6.0e+02  6.2e+00  3.8e+02   9.0e+00   5.1e+02   1.0e+03  3.7e+03  3.3e+02  1.0e+00
# divergent__      0.0e+00      nan  0.0e+00   0.0e+00   0.0e+00   0.0e+00      nan      nan      nan
# energy__         5.0e+01  4.8e-02  1.9e+00   4.8e+01   5.0e+01   5.4e+01  1.5e+03  1.4e+02  1.0e+00
# sigma            9.8e-01  1.4e-03  7.0e-02   8.8e-01   9.8e-01   1.1e+00  2.4e+03  2.2e+02  1.0e+00
# alpha            3.7e+08  3.2e+08  1.3e+09  -1.6e+09   6.1e+07   2.7e+09  1.6e+01  1.4e+00  1.1e+00
# a1               1.4e-01  1.4e-01  7.0e+00  -1.2e+01   2.7e-01   1.2e+01  2.4e+03  2.2e+02  1.0e+00
# a2              -1.4e-01  1.4e-01  7.0e+00  -1.2e+01  -2.3e-01   1.2e+01  2.4e+03  2.2e+02  1.0e+00
#
# Samples were drawn using hmc with nuts.
# For each parameter, N_Eff is a crude measure of effective sample size,
# and R_hat is the potential scale reduction factor on split chains (at
# convergence, R_hat=1).

# %% [markdown]
# Describe the draws

# %%
describe(chn)
# Out:
# Iterations = 1:1000
# Thinning interval = 1
# Chains = 1,2,3,4
# Samples per chain = 1000
#
# Empirical Posterior Estimates:
#           Mean         SD       Naive SE       MCSE      ESS
# sigma  0.98409324 0.069865522 0.0011046709 0.0014830483 1000
#    a1  0.13749130 6.978298211 0.1103365827 0.1599488415 1000
#    a2 -0.13573113 6.979491980 0.1103554578 0.1600942971 1000
#
# Quantiles:
#           2.5%        25.0%      50.0%     75.0%      97.5%
# sigma   0.85971765  0.9346402  0.9800815 1.0286450  1.1321457
#    a1 -13.23038750 -4.5014850  0.2674815 4.7011625 14.2278325
#    a2 -14.21589000 -4.6980250 -0.2416380 4.4727050 13.2844525

# %% [markdown]
# End of `08/m8.1s.jl`

# %% [markdown]
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
