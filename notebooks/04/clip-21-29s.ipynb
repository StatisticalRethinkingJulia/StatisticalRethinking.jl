# %% [markdown]
# Load Julia packages (libraries) needed  for the snippets in chapter 0

# %%
using StatisticalRethinking, CmdStan, StanMCMCChain
gr(size=(500,500));

# %% [markdown]
# CmdStan uses a tmp directory to store the output of cmdstan

# %%
ProjDir = rel_path("..", "scripts", "04")
cd(ProjDir)

# %% [markdown]
# Use data from m4.1s

# %% [markdown]
# Check if the m4.1s.jls file is present. If not, run the model.

# %%
!isfile(joinpath(ProjDir, "m4.1s.jls")) && include(joinpath(ProjDir, "m4.1s.jl"))

chn = deserialize(joinpath(ProjDir, "m4.1s.jls"))
# Out:
# Object of type "Chains{Float64}"
#
# Iterations = 1:1000
# Thinning interval = 1
# Chains = 1,2,3,4
# Samples per chain = 1000
#
# Union{Missing, Float64}[8.20584 155.019; 8.06729 155.334; … ; 7.89613 154.395; 7.84559 154.402]
#
# Union{Missing, Float64}[8.31785 154.655; 7.26654 155.071; … ; 7.83834 155.314; 7.69143 153.821]
#
# Union{Missing, Float64}[7.51074 154.758; 7.4518 154.884; … ; 7.94118 153.978; 7.44499 154.427]
#
# Union{Missing, Float64}[7.2328 154.683; 7.3516 154.669; … ; 8.06108 154.912; 7.55231 154.674]

# %% [markdown]
# Describe the draws

# %%
describe(chn)
# Out:
# Iterations = 1:1000
# Thinning interval = 1
# Chains = 1,2,3,4
# Samples per chain = 1000
#
# Empirical Posterior Estimates:
#           Mean        SD       Naive SE       MCSE     ESS
# sigma   7.7732561 0.29879182 0.0047243134 0.005428545 1000
#    mu 154.6144025 0.41008226 0.0064839698 0.006982701 1000
#
# Quantiles:
#           2.5%      25.0%      50.0%      75.0%       97.5%
# sigma   7.2012405   7.55938   7.761315   7.9715075   8.385718
#    mu 153.8190000 154.33700 154.608500 154.8902500 155.419025

# %% [markdown]
# ### snippet 4.15

# %%
scatter(chn.value[:, 2, 1], chn.value[:, 1, 1])
# Out:
# Plot{Plots.GRBackend() n=1}

# %% [markdown]
# End of `clip-14-29s.jl`

# %% [markdown]
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
